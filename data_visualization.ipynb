# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
BEimmo = pd.read_csv('my_clean_data.csv')
df = pd.DataFrame(BEimmo)

# %%
df.head(10)
# Out:
#    Unnamed: 0          id       type      subtype  bedroomCount  \
# 0           0  20661494.0  APARTMENT    APARTMENT           2.0
# 1           1  20647642.0      HOUSE        HOUSE           4.0
# 2           2  20644816.0  APARTMENT    APARTMENT           2.0
# 3           3  20659813.0  APARTMENT    APARTMENT           2.0
# 4           4  20633249.0  APARTMENT  FLAT_STUDIO           1.0
# 5           5  20639359.0  APARTMENT    APARTMENT           2.0
# 6           6  20634658.0  APARTMENT       DUPLEX           3.0
# 7           7  20634657.0  APARTMENT       DUPLEX           3.0
# 8           8  20634655.0  APARTMENT       DUPLEX           2.0
# 9           9  20651309.0  APARTMENT    APARTMENT           1.0
#
#    bathroomCount  province   locality  postCode  habitableSurface  ...  \
# 0            1.0  Brussels  Etterbeek      1040             100.0  ...
# 1            2.0  Brussels  Etterbeek      1040             270.0  ...
# ...

# %%
sns.catplot(x='type',y='price',data=df)

# %%
sns.catplot(x='province',y='price',data=df, hue='type')

# %%
#show if the distribution is normal
sns.displot(df['price'])

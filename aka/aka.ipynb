# %% [markdown]
# # Import libraries

# %%
pip install folium
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: folium in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from folium) (2.2.3)
# Requirement already satisfied: requests in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akava\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (2024.12.14)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import os
import folium
import pgeocode

# %%
 # Load the data
current_dir = os.getcwd()
print (f"Current directory: {current_dir}")
csv_dir = current_dir.replace('aka', 'datasets\\Kangaroo.csv')
df = pd.read_csv(csv_dir)
df.head(10)
# Out:
# Current directory: c:\dev\BecodeProject\immo-eliza-data-exploration-istanbul\aka
#    Unnamed: 0          id                                                url  \
# 0           0  20661494.0  https://www.immoweb.be/en/classified/apartment...
# 1           1  20647642.0  https://www.immoweb.be/en/classified/house/for...
# 2           2  20644816.0  https://www.immoweb.be/en/classified/apartment...
# 3           3  20659813.0  https://www.immoweb.be/en/classified/apartment...
# 4           4  20633249.0  https://www.immoweb.be/en/classified/flat-stud...
# 5           5  20639359.0  https://www.immoweb.be/en/classified/apartment...
# 6           6  20634658.0  https://www.immoweb.be/en/classified/duplex/fo...
# 7           7  20634657.0  https://www.immoweb.be/en/classified/duplex/fo...
# 8           8  20634655.0  https://www.immoweb.be/en/classified/duplex/fo...
# 9           9  20651309.0  https://www.immoweb.be/en/classified/apartment...
#
#         type      subtype  bedroomCount  bathroomCount  province   locality  \
# 0  APARTMENT    APARTMENT           2.0            1.0  Brussels  Etterbeek
# 1      HOUSE        HOUSE           4.0            2.0  Brussels  Etterbeek
# 2  APARTMENT    APARTMENT           2.0            1.0  Brussels  Etterbeek
# 3  APARTMENT    APARTMENT           2.0            2.0  Brussels  Bruxelles
# 4  APARTMENT  FLAT_STUDIO           1.0            1.0  Brussels  Etterbeek
# 5  APARTMENT    APARTMENT           2.0            1.0  Brussels  ETTERBEEK
# 6  APARTMENT       DUPLEX           3.0            2.0  Brussels  Etterbeek
# 7  APARTMENT       DUPLEX           3.0            2.0  Brussels  Etterbeek
# 8  APARTMENT       DUPLEX           2.0            1.0  Brussels  Etterbeek
# 9  APARTMENT    APARTMENT           1.0            1.0  Brussels  Etterbeek
#
#    postCode  ...  hasOffice  toiletCount  hasSwimmingPool hasFireplace  \
# 0      1040  ...        NaN          1.0              NaN          NaN
# 1      1040  ...       True          3.0              NaN          NaN
# 2      1040  ...        NaN          1.0              NaN          NaN
# 3      1040  ...        NaN          2.0              NaN          NaN
# 4      1040  ...        NaN          1.0              NaN          NaN
# 5      1040  ...        NaN          1.0              NaN          NaN
# 6      1040  ...       True          4.0              NaN          NaN
# 7      1040  ...       True          4.0              NaN          NaN
# 8      1040  ...       True          2.0              NaN          NaN
# 9      1040  ...        NaN          1.0              NaN          NaN
#
#   hasTerrace terraceSurface  terraceOrientation accessibleDisabledPeople  \
# 0       True            7.0                 NaN                      NaN
# 1       True            1.0                 NaN                      NaN
# 2       True            2.0                 NaN                      NaN
# 3       True            3.0                 NaN                      NaN
# 4        NaN            NaN                 NaN                      NaN
# 5       True            2.0                 NaN                      NaN
# 6       True           25.0          SOUTH_WEST                      NaN
# 7       True           25.0          SOUTH_WEST                      NaN
# 8       True           25.0          SOUTH_WEST                      NaN
# 9       True            5.0                EAST                      NaN
#
#   epcScore     price
# 0        C  399000.0
# 1        E  895000.0
# 2        F  465000.0
# 3        B  590000.0
# 4        E  289000.0
# 5        D  375000.0
# 6        D  950000.0
# 7        D  950000.0
# 8        C  795000.0
# 9        F  297000.0
#
# [10 rows x 53 columns]

# %%
# Number of rows and columns
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print(f"Columns: {df.columns.tolist()}")

# Check for missing values
print("Missing values:")
print(f"Price null : {df["price"].isnull().count()}")
print(f"Price null after drop : {df["price"].count()}")
df = df.dropna(subset=["price"])

print(f"habitableSurface null : {df["habitableSurface"].isnull().count()}")
print(f"facedeCount null : {df["facedeCount"].isnull().count()}")

df = df.fillna({
    "hasGarden": False,
    "hasTerrace": False,
    "hasBalcony": False,
    "hasCellar": False,
    "hasPool": False,
    "gardenSurface": 0,
    "terraceSurface": 0,
    "parkingCountOutdoor": 0,
    "parkingCountIndoor": 0,
    "hasFireplace": False,
})
# Out:
# Number of rows: 80368
# Number of columns: 55
# Columns: ['Unnamed: 0', 'id', 'url', 'type', 'subtype', 'bedroomCount', 'bathroomCount', 'province', 'locality', 'postCode', 'habitableSurface', 'roomCount', 'monthlyCost', 'hasAttic', 'hasBasement', 'hasDressingRoom', 'diningRoomSurface', 'hasDiningRoom', 'buildingCondition', 'buildingConstructionYear', 'facedeCount', 'floorCount', 'streetFacadeWidth', 'hasLift', 'floodZoneType', 'heatingType', 'hasHeatPump', 'hasPhotovoltaicPanels', 'hasThermicPanels', 'kitchenSurface', 'kitchenType', 'landSurface', 'hasLivingRoom', 'livingRoomSurface', 'hasBalcony', 'hasGarden', 'gardenSurface', 'gardenOrientation', 'parkingCountIndoor', 'parkingCountOutdoor', 'hasAirConditioning', 'hasArmoredDoor', 'hasVisiophone', 'hasOffice', 'toiletCount', 'hasSwimmingPool', 'hasFireplace', 'hasTerrace', 'terraceSurface', 'terraceOrientation', 'accessibleDisabledPeople', 'epcScore', 'price', 'Latitude', 'Longitude']
# Missing values:
# Price null : 80368
# Price null after drop : 76370
# habitableSurface null : 76370
# facedeCount null : 76370

# %%
nomi = pgeocode.Nominatim('be')
# Get the coordinates 

df["Latitude"] = (nomi.query_postal_code(list(map(str,df["postCode"].tolist()))).latitude)
df["Longitude"] = (nomi.query_postal_code(list(map(str,df["postCode"].tolist()))).longitude)

df_map = df.drop_duplicates(subset=["postCode"])




df.head(25)
center_coordinates =nomi.query_postal_code(1000)  # Get the coordinates of the first row
# Create a map centered around the average latitude and longitude
map_center = df_map[['Latitude', 'Longitude']].mean()

map_plot = folium.Map(location=[center_coordinates.latitude,center_coordinates.longitude], zoom_start=8, control_scale=True)   

df_map = df.drop_duplicates(subset=["postCode"], keep='first') 
print(f"Total original postCode : {df.shape[0]}")
print(f"Total duplicated postCode : {df_map.shape[0]}")
print(f"Total original postCode : {df.duplicated(subset=["postCode"]).sum()}")
print(f"Total duplicated postCode : {df_map.duplicated(subset=["postCode"]).sum()}")

for grp_name, df_grp in df_map.groupby('locality'):
    feature_group = folium.FeatureGroup(grp_name)
    for row in df_grp.itertuples():
        count = df[df['postCode'] == row.postCode].shape[0]  # Count occurrences of the postcode in the original DataFram
        meanPrice = df[df['postCode'] == row.postCode]['price'].mean()  # Calculate mean price for the postcode
        maxPrice = df[df['postCode'] == row.postCode]['price'].max()  # Calculate max price for the postcode
        minPrice = df[df['postCode'] == row.postCode]['price'].min()  # Calculate min price for the postcode
        html = f"""
                <h1> <b>{row.postCode} : {grp_name}</b></h1><br>
                <h2><b> Total sells : {count}</b></h2><br>
                <h2> <b> Mean Price : {meanPrice:.0f} €</b></h2><br>
                <h2> <b> Max Price : {maxPrice:.0f} €</b></h2><br>
                <h2> <b> Min Price : {minPrice:.0f} €</b></h2><br>
                """
        popup = folium.Popup(html, max_width=350)
        folium.CircleMarker(
            location=[row.Latitude, row.Longitude],
            popup=popup,
            radius=5, # define how big you want the circle markers to be
            color="yellow",
            fill=True,
            fill_color="blue",
            fill_opacity=0.6).add_to(feature_group),
    feature_group.add_to(map_plot)

# Add LayerControl to toggle FeatureGroups
folium.LayerControl().add_to(map_plot)


# Save the map to an HTML file
map_plot.save("map_plot.html")
map_plot
# Out:
# Total original postCode : 80368
# Total duplicated postCode : 1100
# Total original postCode : 79268
# Total duplicated postCode : 0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b391ab6cdd75c493c4ca07406cf189b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b391ab6cdd75c493c4ca07406cf189b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b391ab6cdd75c493c4ca07406cf189b9 = L.map(
#                 &quot;map_b391ab6cdd75c493c4ca07406cf189b9&quot;,
#                 {
#                     center: [50.8504, 4.3488],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b391ab6cdd75c493c4ca07406cf189b9);
#
#
#
#
#
#             var tile_layer_4f92b75bdd7b86fcac62f704c35dc811 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f92b75bdd7b86fcac62f704c35dc811.addTo(map_b391ab6cdd75c493c4ca07406cf189b9);
#
#
#             var feature_group_9c2b7e2729670d38890c9555cd466329 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_847b12e16440bd4e22083b74e2545585 = L.circleMarker(
#                 [50.9767, 4.8205],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_9c2b7e2729670d38890c9555cd466329);
#
#
#         var popup_6c6ab73fc5f1e2c05c810f341659b154 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_2f25e0bebf084a402b10dc87ea15ffa2 = $(`&lt;div id=&quot;html_2f25e0bebf084a402b10dc87ea15ffa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;h1&gt; &lt;b&gt;3200 : AARSCHOT&lt;/b&gt;&lt;/h1&gt;&lt;br&gt;                 &lt;h2&gt;&lt;b&gt; Total sells : 134&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;h2&gt; &lt;b&gt; Mean Price : 387485 €&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;h2&gt; &lt;b&gt; Max Price : 1200000 €&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;h2&gt; &lt;b&gt; Min Price : 120000 €&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;/div&gt;`)[0];
#                 popup_6c6ab73fc5f1e2c05c810f341659b154.setContent(html_2f25e0bebf084a402b10dc87ea15ffa2);
#
#
#
#         circle_marker_847b12e16440bd4e22083b74e2545585.bindPopup(popup_6c6ab73fc5f1e2c05c810f341659b154)
#         ;
#
#
#
#
#             var circle_marker_4e26a378eb2ce08ff4f79da72b5e4d6f = L.circleMarker(
#                 [50.9738, 4.8918],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_9c2b7e2729670d38890c9555cd466329);
#
#
#         var popup_ec5d6ab2b69c7bd8415207f4d29f388b = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_f1a0c22ddce521787c70de6c9a97bd46 = $(`&lt;div id=&quot;html_f1a0c22ddce521787c70de6c9a97bd46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;h1&gt; &lt;b&gt;3202 : AARSCHOT&lt;/b&gt;&lt;/h1&gt;&lt;br&gt;                 &lt;h2&gt;&lt;b&gt; Total sells : 22&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;h2&gt; &lt;b&gt; Mean Price : 380977 €&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;h2&gt; &lt;b&gt; Max Price : 995000 €&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;h2&gt; &lt;b&gt; Min Price : 165000 €&lt;/b&gt;&lt;/h2&gt;&lt;br&gt;                 &lt;/div&gt;`)[0];
#                 popup_ec5d6ab2b69c7bd8415207f4d29f388b.setContent(html_f1a0c22ddce521787c70de6c9a97bd46);
#
#
#
#         circle_marker_4e26a378eb2ce08ff4f79da72b5e4d6f.bindPopup(popup_ec5d6ab2b69c7bd8415207f4d29f388b)
#         ;
#
#
#
#
#             feature_group_9c2b7e2729670d38890c9555cd466329.addTo(map_b391ab6cdd75c493c4ca07406cf189b9);
#
#
#             var feature_group_fb5e449a71f93146770490e0703b026d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_edea23ec64a001e48f43e489617cda1b = L.circleMarker(
#                 [51.1341, 4.3868],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:
